# %%
import os
import torch

for path in [
    "/home/hsushang/skip-gram/output/LosAngeles_lr0.01.pt",
    "/home/hsushang/TrajGPT/output/trajgpt_LosAngeles_lr0.001.pt",
    "/home/hsushang/GETNext/output/getnext_LosAngeles_lr0.0003.pt",
    "/home/hsushang/skip-gram/output/Houston_lr0.01.pt",
    "/home/hsushang/TrajGPT/output/trajgpt_Houston_lr0.001.pt",
    "/home/hsushang/GETNext/output/getnext_Houston_lr0.0003.pt",
]:
    if os.path.exists(path) is False:
        print(f"File not found: {path}")
        continue
    
    poi_dict = torch.load(path)
    print(path)
    print(" ", len(poi_dict), poi_dict[0].shape)

# %%
import pandas as pd

# city = "Houston"
city = "LosAngeles"
data_path = f"/data/private/maria_data/data/trajfm_veraset_splits/veraset/Visits/{city}/whole_veraset_processed.parquet"
df = pd.read_parquet(
    data_path,
    columns=[
        "user_id",
        "place_lon",
        "place_lat",
        "arrival_time",
        "departure_time",
        "place_id",
    ],
)

# %%
pd.to_datetime(df['arrival_time'])

# %%
df['departure_time']

# %%
type(df['arrival_time'].iloc[0])

# %%
oldest_timestamp = df["arrival_time"].min()
((df["arrival_time"] - oldest_timestamp).dt.total_seconds() / (
    60 * 60 * 24
))
